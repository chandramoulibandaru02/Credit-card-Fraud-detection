# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.isnull()
# Out:
#          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# 284806  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data['Amount']
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
print(data['Amount'])
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
data['Amount']=scaler.fit_transform(data[['Amount']])

# %%
data['Amount'].shape
# Out:
# (284807,)

# %%
data['Amount']
# Out:
# 0         0.244964
# 1        -0.342475
# 2         1.160686
# 3         0.140534
# 4        -0.073403
#             ...
# 284802   -0.350151
# 284803   -0.254117
# 284804   -0.081839
# 284805   -0.313249
# 284806    0.514355
# Name: Amount, Length: 284807, dtype: float64

# %%
x=data.drop(columns=['Class'])

# %%
y=data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (170884, 30)
# (113923, 30)
# (170884,)
# (113923,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN=KNeighborsClassifier(n_neighbors=5)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=KNN.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y_test,y_pred)

# %%
print((acc*100)," IS the accuracy of this model")
# Out:
# 99.84726525811294  IS the accuracy of this model

# %%
err=[]
for i in range(1,21):
    K=KNeighborsClassifier(n_neighbors=i)
    K.fit(x_train,y_train)
    sc=K.predict(x_test)
    err.append(np.mean(sc!=y_test))

# %%
for i in err:
    print(i)
# Out:
# 0.0003774479253530894
# 7.022286983313291e-05
# 7.022286983313291e-05
# 0.0
# 0.0
# 1.7555717458283227e-05
# 2.633357618742484e-05
# 5.266715237484968e-05
# 6.14450111039913e-05
# 7.900072856227452e-05
# 7.900072856227452e-05
# 7.900072856227452e-05
# 7.900072856227452e-05
# 0.00010533430474969936
# 9.655644602055774e-05
# 0.00010533430474969936
# 0.00010533430474969936
# 0.00010533430474969936
# 0.00010533430474969936
# 0.0001228900222079826

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.plot(range(1,21,1),err,marker='o',linestyle='dashed',color='red',markersize=5)
plt.xlabel('K')
plt.ylabel('ERR')
plt.title("Finding best value of K with low error")
plt.xticks(range(1,21))
plt.show()

# %%
print("Therfore we are getting low error at K=1")
# Out:
# Therfore we are getting low error at K=1

# %%
KNNN=KNeighborsClassifier(n_neighbors=1)

# %%
arr=[1.23, -0.87, 0.34, -1.22, 2.11, -3.45, 1.56, -0.98, 0.67, -1.45,
                      2.56, -3.21, 1.78, -0.56, 0.12, -1.89, 3.21, -2.45, 0.89, -1.23,
                      2.98, -3.67, 1.45, -0.76, 0.23, -1.56, 3.12, -2.89, -4.5,250.75]

# %%
df=pd.DataFrame([arr],columns=x_test.columns)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
S=StandardScaler()
df['Amount']=S.fit_transform([df['Amount']])

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
c=KNN.predict(df)

# %%
print("No fraud detected" if (c==0) else "Fraud detected")
# Out:
# No fraud detected
